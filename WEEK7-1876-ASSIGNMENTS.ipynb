# %% [markdown]
# <a href="https://colab.research.google.com/github/2303A51876/CP_1876_BT-14/blob/main/WEEK7-1876-ASSIGNMENTS.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#T.shylasri(2303A51876)
#WEEK-7 ASSIGNMENT-1
#Friday Lab-(06-02-26)
class TrieNode:
    def __init__(self):
        self.children = {}
        self.is_end = False
class Trie:
    def __init__(self):
        self.root = TrieNode()
    def insert(self, word):
        node = self.root
        for ch in word:
            if ch not in node.children:
                node.children[ch] = TrieNode()
            node = node.children[ch]
        node.is_end = True
    def search(self, word):
        node = self.root
        for ch in word:
            if ch not in node.children:
                return False
            node = node.children[ch]
        return node.is_end
    def startsWith(self, prefix):
        node = self.root
        for ch in prefix:
            if ch not in node.children:
                return False
            node = node.children[ch]
        return True
trie = Trie()
n = int(input("Enter number of book titles: "))
print("Enter book titles:")
for _ in range(n):
    title = input().strip()
    trie.insert(title)
search1 = input("Enter book title to search: ")
search2 = input("Enter another book title to search: ")
prefix1 = input("Enter prefix to check: ")
prefix2 = input("Enter another prefix to check: ")
print(f'Book "{search1}" found → {trie.search(search1)}')
print(f'Book "{search2}" found → {trie.search(search2)}')
print(f'Prefix "{prefix1}" exists → {trie.startsWith(prefix1)}')
print(f'Prefix "{prefix2}" exists → {trie.startsWith(prefix2)}')
# Out:
# Enter number of book titles: 5
# Enter book titles:
# Data
# Database
# DataScience
# Design
# Development
# Enter book title to search: Data
# Enter another book title to search: DataMining
# Enter prefix to check: Data
# Enter another prefix to check: Dev
# Book "Data" found → True
# Book "DataMining" found → False
# Prefix "Data" exists → True
# Prefix "Dev" exists → True

# %%
#T.shylasri(2303A51876)
#WEEK-7 ASSIGNMENT-2
#Friday Lab-(06-02-26)
class TrieNode:
    def __init__(self):
        self.children = {}
        self.is_end = False
class Trie:
    def __init__(self):
        self.root = TrieNode()
    def insert(self, word):
        node = self.root
        for ch in word:
            if ch not in node.children:
                node.children[ch] = TrieNode()
            node = node.children[ch]
        node.is_end = True
    def search(self, word):
        node = self.root
        for ch in word:
            if ch not in node.children:
                return False
            node = node.children[ch]
        return node.is_end
    def startsWith(self, prefix):
        node = self.root
        for ch in prefix:
            if ch not in node.children:
                return False
            node = node.children[ch]
        return True
trie = Trie()
n = int(input("Enter number of contacts: "))
print("Enter contact names:")
for _ in range(n):
    name = input().strip()
    trie.insert(name)
s1 = input("Enter contact name to search: ")
s2 = input("Enter another contact name to search: ")
p1 = input("Enter prefix to check: ")
p2 = input("Enter another prefix to check: ")
print(f'Contact "{s1}" found → {trie.search(s1)}')
print(f'Contact "{s2}" found → {trie.search(s2)}')
print(f'Prefix "{p1}" exists → {trie.startsWith(p1)}')
print(f'Prefix "{p2}" exists → {trie.startsWith(p2)}')
# Out:
# Enter number of contacts: 5
# Enter contact names:
# Anil
# Anitha
# Anirudh
# Bala
# Balaji
# Enter contact name to search: Anil
# Enter another contact name to search: Anand
# Enter prefix to check: Ani
# Enter another prefix to check: Bal
# Contact "Anil" found → True
# Contact "Anand" found → False
# Prefix "Ani" exists → True
# Prefix "Bal" exists → True
